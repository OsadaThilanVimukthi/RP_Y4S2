# %% [markdown]
# # Data Preprocessing - Dataset Analysis
# v1.0 - The script is performing data preprocessing and analysis on the dataset.

# %% [markdown]
# ### Import the required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the dataset

# %%
data_file = "./Datasets/final_wholesale_retail_dataset_v0.0.csv"
dataset = pd.read_csv(data_file)

# %% [markdown]
# ### Display the first few rows of the dataset to get an overview

# %%
print(dataset.head())
# Out:
#    year  month     location  wholesale_price  retail_price
# 0  2017      1  Keppetipola            45.42          98.0
# 1  2017      1   Kurunegala            61.00         103.0
# 2  2017      1       Ampara            73.91         124.8
# 3  2017      1       Matale            68.94         116.4
# 4  2017      1     Vavuniya            46.19          78.0

# %% [markdown]
# ### Separate independent (X) and dependent (y) variables

# %%
X = dataset.iloc[:, :-2]  # Select all columns except the last two
y = dataset.iloc[:, -2:]  # Select the last two columns

# %% [markdown]
# ### Display the first few rows of X and y

# %%
print("Independent variables (X):")
print(X.head())

print("\nDependent variables (y):")
print(y.head())
# Out:
# Independent variables (X):
#    year  month     location
# 0  2017      1  Keppetipola
# 1  2017      1   Kurunegala
# 2  2017      1       Ampara
# 3  2017      1       Matale
# 4  2017      1     Vavuniya
#
# Dependent variables (y):
#    wholesale_price  retail_price
# 0            45.42          98.0
# 1            61.00         103.0
# 2            73.91         124.8
# 3            68.94         116.4
# 4            46.19          78.0

# %% [markdown]
# ## Dataset Analysis

# %% [markdown]
# ### Summary Statistics

# %%
print("Summary Statistics:")
print(dataset.describe())
# Out:
# Summary Statistics:
#               year        month  wholesale_price  retail_price
# count  2626.000000  2626.000000      2626.000000   2626.000000
# mean   2019.493907     6.535034        55.953043    102.345366
# std       1.718737     3.464722        26.048325     35.729357
# min    2017.000000     1.000000        10.300000     32.000000
# 25%    2018.000000     3.000000        37.500000     76.000000
# 50%    2019.000000     7.000000        48.560000     95.000000
# 75%    2021.000000    10.000000        69.487500    121.082500
# max    2022.000000    12.000000       171.500000    238.330000

# %% [markdown]
# ### Time Series Plot

# %%
plt.figure(figsize=(20, 8))
plt.plot(dataset['year'].astype(str) + '-' + dataset['month'].astype(str), 
            dataset['wholesale_price'], label='Wholesale Price', marker='o', linestyle='-', color='blue')
plt.plot(dataset['year'].astype(str) + '-' + dataset['month'].astype(str), 
            dataset['retail_price'], label='Retail Price', marker='o', linestyle='-', color='orange')
plt.title('Monthly Price Trends')
plt.xlabel('Year-Month')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Correlation Analysis

# %%
correlation_matrix = dataset[['wholesale_price', 'retail_price']].corr()

# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(6, 6))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.title('Correlation Heatmap (wholesale_price & retail_price)')
plt.xticks([0, 1], ['wholesale_price', 'retail_price'])
plt.yticks([0, 1], ['wholesale_price', 'retail_price'])
plt.show()

# %% [markdown]
# ### Histograms
# #### Distribution of Price data - After Imputation

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(dataset['wholesale_price'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Wholesale Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.subplot(1, 2, 2)
plt.hist(dataset['retail_price'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Retail Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---------------------
