#   inflating: VegetableImages/validation/Tomato/1263.jpg
#   inflating: VegetableImages/validation/Tomato/1264.jpg
#   inflating: VegetableImages/validation/Tomato/1265.jpg
#   inflating: VegetableImages/validation/Tomato/1266.jpg
#   inflating: VegetableImages/validation/Tomato/1267.jpg
#   inflating: VegetableImages/validation/Tomato/1268.jpg
#   inflating: VegetableImages/validation/Tomato/1269.jpg
#   inflating: VegetableImages/validation/Tomato/1270.jpg
#   inflating: VegetableImages/validation/Tomato/1271.jpg
#   inflating: VegetableImages/validation/Tomato/1272.jpg
#   inflating: VegetableImages/validation/Tomato/1273.jpg
#   inflating: VegetableImages/validation/Tomato/1274.jpg
#   inflating: VegetableImages/validation/Tomato/1275.jpg
#   inflating: VegetableImages/validation/Tomato/1276.jpg
#   inflating: VegetableImages/validation/Tomato/1277.jpg
#   inflating: VegetableImages/validation/Tomato/1278.jpg
#   inflating: VegetableImages/validation/Tomato/1279.jpg
#   inflating: VegetableImages/validation/Tomato/1280.jpg
#   inflating: VegetableImages/validation/Tomato/1281.jpg
#   inflating: VegetableImages/validation/Tomato/1282.jpg
#   inflating: VegetableImages/validation/Tomato/1283.jpg
#   inflating: VegetableImages/validation/Tomato/1284.jpg
#   inflating: VegetableImages/validation/Tomato/1285.jpg
#   inflating: VegetableImages/validation/Tomato/1286.jpg
#   inflating: VegetableImages/validation/Tomato/1287.jpg
#   inflating: VegetableImages/validation/Tomato/1288.jpg
#   inflating: VegetableImages/validation/Tomato/1289.jpg
#   inflating: VegetableImages/validation/Tomato/1290.jpg
#   inflating: VegetableImages/validation/Tomato/1291.jpg
#   inflating: VegetableImages/validation/Tomato/1292.jpg
#   inflating: VegetableImages/validation/Tomato/1293.jpg
#   inflating: VegetableImages/validation/Tomato/1294.jpg
#   inflating: VegetableImages/validation/Tomato/1295.jpg
#   inflating: VegetableImages/validation/Tomato/1296.jpg
#   inflating: VegetableImages/validation/Tomato/1297.jpg
#   inflating: VegetableImages/validation/Tomato/1298.jpg
#   inflating: VegetableImages/validation/Tomato/1299.jpg
#   inflating: VegetableImages/validation/Tomato/1300.jpg
#   inflating: VegetableImages/validation/Tomato/1301.jpg
#   inflating: VegetableImages/validation/Tomato/1302.jpg
#   inflating: VegetableImages/validation/Tomato/1303.jpg
#   inflating: VegetableImages/validation/Tomato/1304.jpg
#   inflating: VegetableImages/validation/Tomato/1305.jpg
#   inflating: VegetableImages/validation/Tomato/1306.jpg
#   inflating: VegetableImages/validation/Tomato/1307.jpg
#   inflating: VegetableImages/validation/Tomato/1308.jpg
#   inflating: VegetableImages/validation/Tomato/1309.jpg
#   inflating: VegetableImages/validation/Tomato/1310.jpg
#   inflating: VegetableImages/validation/Tomato/1311.jpg
#   inflating: VegetableImages/validation/Tomato/1312.jpg
#   inflating: VegetableImages/validation/Tomato/1313.jpg
#   inflating: VegetableImages/validation/Tomato/1314.jpg
#   inflating: VegetableImages/validation/Tomato/1315.jpg
#   inflating: VegetableImages/validation/Tomato/1316.jpg
#   inflating: VegetableImages/validation/Tomato/1317.jpg
#   inflating: VegetableImages/validation/Tomato/1318.jpg
#   inflating: VegetableImages/validation/Tomato/1319.jpg
#   inflating: VegetableImages/validation/Tomato/1320.jpg
#   inflating: VegetableImages/validation/Tomato/1321.jpg
#   inflating: VegetableImages/validation/Tomato/1322.jpg
#   inflating: VegetableImages/validation/Tomato/1323.jpg
#   inflating: VegetableImages/validation/Tomato/1324.jpg
#   inflating: VegetableImages/validation/Tomato/1325.jpg
#   inflating: VegetableImages/validation/Tomato/1326.jpg
#   inflating: VegetableImages/validation/Tomato/1327.jpg
#   inflating: VegetableImages/validation/Tomato/1328.jpg
#   inflating: VegetableImages/validation/Tomato/1329.jpg
#   inflating: VegetableImages/validation/Tomato/1330.jpg
#   inflating: VegetableImages/validation/Tomato/1331.jpg
#   inflating: VegetableImages/validation/Tomato/1332.jpg
#   inflating: VegetableImages/validation/Tomato/1333.jpg
#   inflating: VegetableImages/validation/Tomato/1334.jpg
#   inflating: VegetableImages/validation/Tomato/1335.jpg
#   inflating: VegetableImages/validation/Tomato/1336.jpg
#   inflating: VegetableImages/validation/Tomato/1337.jpg
#   inflating: VegetableImages/validation/Tomato/1338.jpg
#   inflating: VegetableImages/validation/Tomato/1339.jpg
#   inflating: VegetableImages/validation/Tomato/1340.jpg
#   inflating: VegetableImages/validation/Tomato/1341.jpg
#   inflating: VegetableImages/validation/Tomato/1342.jpg
#   inflating: VegetableImages/validation/Tomato/1343.jpg
#   inflating: VegetableImages/validation/Tomato/1344.jpg
#   inflating: VegetableImages/validation/Tomato/1345.jpg
#   inflating: VegetableImages/validation/Tomato/1346.jpg
#   inflating: VegetableImages/validation/Tomato/1347.jpg
#   inflating: VegetableImages/validation/Tomato/1348.jpg
#   inflating: VegetableImages/validation/Tomato/1349.jpg
#   inflating: VegetableImages/validation/Tomato/1350.jpg
#   inflating: VegetableImages/validation/Tomato/1351.jpg
#   inflating: VegetableImages/validation/Tomato/1352.jpg
#   inflating: VegetableImages/validation/Tomato/1353.jpg
#   inflating: VegetableImages/validation/Tomato/1354.jpg
#   inflating: VegetableImages/validation/Tomato/1355.jpg
#   inflating: VegetableImages/validation/Tomato/1356.jpg
#   inflating: VegetableImages/validation/Tomato/1357.jpg
#   inflating: VegetableImages/validation/Tomato/1358.jpg
#   inflating: VegetableImages/validation/Tomato/1359.jpg
#   inflating: VegetableImages/validation/Tomato/1360.jpg
#   inflating: VegetableImages/validation/Tomato/1361.jpg
#   inflating: VegetableImages/validation/Tomato/1362.jpg
#   inflating: VegetableImages/validation/Tomato/1363.jpg
#   inflating: VegetableImages/validation/Tomato/1364.jpg
#   inflating: VegetableImages/validation/Tomato/1365.jpg
#   inflating: VegetableImages/validation/Tomato/1366.jpg
#   inflating: VegetableImages/validation/Tomato/1367.jpg
#   inflating: VegetableImages/validation/Tomato/1368.jpg
#   inflating: VegetableImages/validation/Tomato/1369.jpg
#   inflating: VegetableImages/validation/Tomato/1370.jpg
#   inflating: VegetableImages/validation/Tomato/1371.jpg
#   inflating: VegetableImages/validation/Tomato/1372.jpg
#   inflating: VegetableImages/validation/Tomato/1373.jpg
#   inflating: VegetableImages/validation/Tomato/1374.jpg
#   inflating: VegetableImages/validation/Tomato/1375.jpg
#   inflating: VegetableImages/validation/Tomato/1376.jpg
#   inflating: VegetableImages/validation/Tomato/1377.jpg
#   inflating: VegetableImages/validation/Tomato/1378.jpg
#   inflating: VegetableImages/validation/Tomato/1379.jpg
#   inflating: VegetableImages/validation/Tomato/1380.jpg
#   inflating: VegetableImages/validation/Tomato/1381.jpg
#   inflating: VegetableImages/validation/Tomato/1382.jpg
#   inflating: VegetableImages/validation/Tomato/1383.jpg
#   inflating: VegetableImages/validation/Tomato/1384.jpg
#   inflating: VegetableImages/validation/Tomato/1385.jpg
#   inflating: VegetableImages/validation/Tomato/1386.jpg
#   inflating: VegetableImages/validation/Tomato/1387.jpg
#   inflating: VegetableImages/validation/Tomato/1388.jpg
#   inflating: VegetableImages/validation/Tomato/1389.jpg
#   inflating: VegetableImages/validation/Tomato/1390.jpg
#   inflating: VegetableImages/validation/Tomato/1391.jpg
#   inflating: VegetableImages/validation/Tomato/1392.jpg
#   inflating: VegetableImages/validation/Tomato/1393.jpg
#   inflating: VegetableImages/validation/Tomato/1394.jpg
#   inflating: VegetableImages/validation/Tomato/1395.jpg
#   inflating: VegetableImages/validation/Tomato/1396.jpg
#   inflating: VegetableImages/validation/Tomato/1397.jpg
#   inflating: VegetableImages/validation/Tomato/1398.jpg
#   inflating: VegetableImages/validation/Tomato/1399.jpg
#   inflating: VegetableImages/validation/Tomato/1400.jpg

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

plt.ion()

use_gpu = torch.cuda.is_available()
if use_gpu:
    print("Using CUDA")
# Out:
# Using CUDA

# %%
data_dir = '/content/VegetableImages'
TRAIN = 'train'
VAL = 'validation'
TEST = 'test'

data_transforms = {
    TRAIN: transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
    ]),
    VAL: transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
    ]),
    TEST: transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
    ])
}

image_datasets = {
    x: datasets.ImageFolder(
        os.path.join(data_dir, x),
        transform=data_transforms[x]
    )
    for x in [TRAIN, VAL, TEST]
}

dataloaders = {
    x: torch.utils.data.DataLoader(
        image_datasets[x], batch_size=8,
        shuffle=True, num_workers=4
    )
    for x in [TRAIN, VAL, TEST]
}

dataset_sizes = {x: len(image_datasets[x]) for x in [TRAIN, VAL, TEST]}

for x in [TRAIN, VAL, TEST]:
    print("Loaded {} images under {}".format(dataset_sizes[x], x))

print("Classes: ")
class_names = image_datasets[TRAIN].classes
print(image_datasets[TRAIN].classes)
# Out:
# Loaded 15000 images under train
# Loaded 3000 images under validation
# Loaded 3000 images under test
# Classes:
# ['Bean', 'Bitter_Gourd', 'Bottle_Gourd', 'Brinjal', 'Broccoli', 'Cabbage', 'Capsicum', 'Carrot', 'Cauliflower', 'Cucumber', 'Papaya', 'Potato', 'Pumpkin', 'Radish', 'Tomato']
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
len(class_names)
# Out:
# 15

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    # plt.figure(figsize=(10, 10))
    plt.axis('off')
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

def show_databatch(inputs, classes):
    out = torchvision.utils.make_grid(inputs)
    imshow(out, title=[class_names[x] for x in classes])

# Get a batch of training data
inputs, classes = next(iter(dataloaders[TRAIN]))
show_databatch(inputs, classes)

# %%
def visualize_model(vgg, num_images=6):
    was_training = vgg.training

    # Set model for evaluation
    vgg.train(False)
    vgg.eval()

    images_so_far = 0

    for i, data in enumerate(dataloaders[TEST]):
        inputs, labels = data
        size = inputs.size()[0]

        if use_gpu:
            inputs, labels = Variable(inputs.cuda(), volatile=True), Variable(labels.cuda(), volatile=True)
        else:
            inputs, labels = Variable(inputs, volatile=True), Variable(labels, volatile=True)

        outputs = vgg(inputs)

        _, preds = torch.max(outputs.data, 1)
        predicted_labels = [preds[j] for j in range(inputs.size()[0])]

        print("Ground truth:")
        show_databatch(inputs.data.cpu(), labels.data.cpu())
        print("Prediction:")
        show_databatch(inputs.data.cpu(), predicted_labels)

        del inputs, labels, outputs, preds, predicted_labels
        torch.cuda.empty_cache()

        images_so_far += size
        if images_so_far >= num_images:
            break

    vgg.train(mode=was_training) # Revert model back to original training state

# %%
def eval_model(vgg, criterion):
    since = time.time()
    avg_loss = 0
    avg_acc = 0
    loss_test = 0
    acc_test = 0

    test_batches = len(dataloaders[TEST])
    print("Evaluating model")
    print('-' * 10)

    for i, data in enumerate(dataloaders[TEST]):
        if i % 100 == 0:
            print("\rTest batch {}/{}".format(i, test_batches), end='', flush=True)

        vgg.train(False)
        vgg.eval()
        inputs, labels = data

        if use_gpu:
            inputs, labels = Variable(inputs.cuda(), volatile=True), Variable(labels.cuda(), volatile=True)
        else:
            inputs, labels = Variable(inputs, volatile=True), Variable(labels, volatile=True)

        outputs = vgg(inputs)

        _, preds = torch.max(outputs.data, 1)
        loss = criterion(outputs, labels)

        loss_test += loss.item()
        acc_test += torch.sum(preds == labels.data)

        del inputs, labels, outputs, preds
        torch.cuda.empty_cache()

    avg_loss = loss_test / dataset_sizes[TEST]
    avg_acc = acc_test / dataset_sizes[TEST]

    elapsed_time = time.time() - since
    print()
    print("Evaluation completed in {:.0f}m {:.0f}s".format(elapsed_time // 60, elapsed_time % 60))
    print("Avg loss (test): {:.4f}".format(avg_loss))
    print("Avg acc (test): {:.4f}".format(avg_acc))
    print('-' * 10)

# %%
VGG_types = {
    "VGG16": [
        64,
        64,
        "M",
        128,
        128,
        "M",
        256,
        256,
        256,
        "M",
        512,
        512,
        512,
        "M",
        512,
        512,
        512,
        "M",
    ],
}

class VGG_net(nn.Module):
    def __init__(self,input_channels, num_classes = 2):
        super(VGG_net,self).__init__()
        self.in_channels = input_channels
        self.conv_layers = self.create_conv_layers(VGG_types['VGG16']) #create our conv layers
        self.fcs = nn.Sequential(
            nn.Linear(512*7*7, 4096),
                     nn.ReLU(),
                     nn.Dropout(p=0.5),
                     nn.Linear(4096,4096),
                     nn.ReLU(),
                     nn.Dropout(p=0.5),
                     nn.Linear(4096,num_classes) #sizeInputImage = 224, divided by num Maxpool : 224 / 2⁷ = 7
        )
    def forward(self,x):
        x = self.conv_layers(x)
        x = x.reshape(x.shape[0], -1) #flatten our convlayers
        x = self.fcs(x)
        return x
    def create_conv_layers(self,architecture):
        layers = []
        in_channels = self.in_channels
        for layer in architecture :
            if type(layer) is int:
                out_channels = layer
                layers += [nn.Conv2d(in_channels = in_channels,out_channels = out_channels,
                                     kernel_size = (3,3), stride = (1,1), padding = (1,1)),
                                     nn.BatchNorm2d(layer),
                                     nn.ReLU()]
                in_channels = layer #for the next itteration
            elif layer == 'M':
                layers += [nn.MaxPool2d(kernel_size = (2,2), stride = (2,2))]
        return nn.Sequential(*layers,  )

# %%
input_channels = 3
num_classes = len(class_names)
model = VGG_net(input_channels, num_classes)

# Hiển thị thông tin summary
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
print(model)
# Out:
# VGG_net(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU()
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU()
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU()
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU()
#     (23): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU()
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU()
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU()
#     (33): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU()
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU()
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU()
#     (43): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (fcs): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=15, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
def train_model(vgg, criterion, optimizer, scheduler, num_epochs, save_path):
    since = time.time()
    best_model_wts = copy.deepcopy(vgg.state_dict())
    best_acc = 0.0

    avg_loss = 0
    avg_acc = 0
    avg_loss_val = 0
    avg_acc_val = 0

    train_batches = len(dataloaders[TRAIN])
    val_batches = len(dataloaders[VAL])

    for epoch in range(num_epochs):
        print("Epoch {}/{}".format(epoch, num_epochs))
        print('-' * 10)

        loss_train = 0
        loss_val = 0
        acc_train = 0
        acc_val = 0

        vgg.train(True)

        for i, data in enumerate(dataloaders[TRAIN]):
            if i % 100 == 0:
                print("\rTraining batch {}/{}".format(i, train_batches / 2), end='', flush=True)

            # Use half training dataset
            if i >= train_batches / 2:
                break

            inputs, labels = data

            if use_gpu:
                inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
            else:
                inputs, labels = Variable(inputs), Variable(labels)

            optimizer.zero_grad()

            outputs = vgg(inputs)

            _, preds = torch.max(outputs.data, 1)
            loss = criterion(outputs, labels)

            loss.backward()
            optimizer.step()

            loss_train += loss.item()
            acc_train += torch.sum(preds == labels.data)

            del inputs, labels, outputs, preds
            torch.cuda.empty_cache()

        print()
        # * 2 as we only used half of the dataset
        avg_loss = loss_train * 2 / dataset_sizes[TRAIN]
        avg_acc = acc_train * 2 / dataset_sizes[TRAIN]

        vgg.train(False)
        vgg.eval()

        for i, data in enumerate(dataloaders[VAL]):
            if i % 100 == 0:
                print("\rValidation batch {}/{}".format(i, val_batches), end='', flush=True)

            inputs, labels = data

            if use_gpu:
                inputs, labels = Variable(inputs.cuda(), volatile=True), Variable(labels.cuda(), volatile=True)
            else:
                inputs, labels = Variable(inputs, volatile=True), Variable(labels, volatile=True)

            optimizer.zero_grad()

            outputs = vgg(inputs)

            _, preds = torch.max(outputs.data, 1)
            loss = criterion(outputs, labels)

            loss_val += loss.item()
            acc_val += torch.sum(preds == labels.data)

            del inputs, labels, outputs, preds
            torch.cuda.empty_cache()

        avg_loss_val = loss_val / dataset_sizes[VAL]
        avg_acc_val = acc_val / dataset_sizes[VAL]

        print()
        print("Epoch {} result: ".format(epoch))
        print("Avg loss (train): {:.4f}".format(avg_loss))
        print("Avg acc (train): {:.4f}".format(avg_acc))
        print("Avg loss (val): {:.4f}".format(avg_loss_val))
        print("Avg acc (val): {:.4f}".format(avg_acc_val))
        print('-' * 10)
        print()

        # Save model after each epoch
        epoch_save_path = save_path.format(epoch)
        torch.save(vgg.state_dict(), epoch_save_path)
        print("Model saved at:", epoch_save_path)

        if avg_acc_val > best_acc:
            best_acc = avg_acc_val
            best_model_wts = copy.deepcopy(vgg.state_dict())

    elapsed_time = time.time() - since
    print()
    print("Training completed in {:.0f}m {:.0f}s".format(elapsed_time // 60, elapsed_time % 60))
    print("Best acc: {:.4f}".format(best_acc))

    vgg.load_state_dict(best_model_wts)
    return vgg

# %%
model_save_path = '/content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt'
num_epochs = 100
history = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs, model_save_path)
# Out:
# Epoch 0/100
# ----------
# Training batch 900/937.5
# Validation batch 0/375
# <ipython-input-12-62ec528cc992>:71: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs, labels = Variable(inputs.cuda(), volatile=True), Variable(labels.cuda(), volatile=True)
# Validation batch 300/375
# Epoch 0 result:
# Avg loss (train): 0.2628
# Avg acc (train): 0.2977
# Avg loss (val): 0.1661
# Avg acc (val): 0.5743
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 1/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 1 result:
# Avg loss (train): 0.2144
# Avg acc (train): 0.4272
# Avg loss (val): 0.1456
# Avg acc (val): 0.6330
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 2/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 2 result:
# Avg loss (train): 0.1880
# Avg acc (train): 0.5055
# Avg loss (val): 0.1106
# Avg acc (val): 0.6747
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 3/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 3 result:
# Avg loss (train): 0.1702
# Avg acc (train): 0.5552
# Avg loss (val): 0.0874
# Avg acc (val): 0.7780
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 4/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 4 result:
# Avg loss (train): 0.1517
# Avg acc (train): 0.6035
# Avg loss (val): 0.0868
# Avg acc (val): 0.7783
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 5/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 5 result:
# Avg loss (train): 0.1414
# Avg acc (train): 0.6367
# Avg loss (val): 0.0845
# Avg acc (val): 0.7753
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 6/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 6 result:
# Avg loss (train): 0.1313
# Avg acc (train): 0.6671
# Avg loss (val): 0.0601
# Avg acc (val): 0.8547
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 7/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 7 result:
# Avg loss (train): 0.1244
# Avg acc (train): 0.6876
# Avg loss (val): 0.0662
# Avg acc (val): 0.8650
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 8/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 8 result:
# Avg loss (train): 0.1131
# Avg acc (train): 0.7135
# Avg loss (val): 0.0495
# Avg acc (val): 0.8843
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 9/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 9 result:
# Avg loss (train): 0.1096
# Avg acc (train): 0.7285
# Avg loss (val): 0.0753
# Avg acc (val): 0.7913
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 10/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 10 result:
# Avg loss (train): 0.1010
# Avg acc (train): 0.7509
# Avg loss (val): 0.0330
# Avg acc (val): 0.9217
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 11/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 11 result:
# Avg loss (train): 0.0885
# Avg acc (train): 0.7833
# Avg loss (val): 0.0378
# Avg acc (val): 0.9087
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 12/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 12 result:
# Avg loss (train): 0.0883
# Avg acc (train): 0.7792
# Avg loss (val): 0.0254
# Avg acc (val): 0.9337
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 13/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 13 result:
# Avg loss (train): 0.0803
# Avg acc (train): 0.8089
# Avg loss (val): 0.0208
# Avg acc (val): 0.9563
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 14/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 14 result:
# Avg loss (train): 0.0766
# Avg acc (train): 0.8120
# Avg loss (val): 0.0271
# Avg acc (val): 0.9383
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 15/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 15 result:
# Avg loss (train): 0.0719
# Avg acc (train): 0.8265
# Avg loss (val): 0.0244
# Avg acc (val): 0.9500
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 16/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 16 result:
# Avg loss (train): 0.0700
# Avg acc (train): 0.8304
# Avg loss (val): 0.0175
# Avg acc (val): 0.9593
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 17/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 17 result:
# Avg loss (train): 0.0698
# Avg acc (train): 0.8319
# Avg loss (val): 0.0205
# Avg acc (val): 0.9610
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 18/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 18 result:
# Avg loss (train): 0.0638
# Avg acc (train): 0.8447
# Avg loss (val): 0.0213
# Avg acc (val): 0.9570
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 19/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 19 result:
# Avg loss (train): 0.0624
# Avg acc (train): 0.8513
# Avg loss (val): 0.0164
# Avg acc (val): 0.9597
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 20/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 20 result:
# Avg loss (train): 0.0560
# Avg acc (train): 0.8673
# Avg loss (val): 0.0192
# Avg acc (val): 0.9597
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 21/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 21 result:
# Avg loss (train): 0.0568
# Avg acc (train): 0.8587
# Avg loss (val): 0.0283
# Avg acc (val): 0.9297
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 22/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 22 result:
# Avg loss (train): 0.0507
# Avg acc (train): 0.8753
# Avg loss (val): 0.0189
# Avg acc (val): 0.9593
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 23/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 23 result:
# Avg loss (train): 0.0512
# Avg acc (train): 0.8756
# Avg loss (val): 0.0101
# Avg acc (val): 0.9783
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 24/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 24 result:
# Avg loss (train): 0.0493
# Avg acc (train): 0.8792
# Avg loss (val): 0.0081
# Avg acc (val): 0.9863
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 25/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 25 result:
# Avg loss (train): 0.0433
# Avg acc (train): 0.8956
# Avg loss (val): 0.0103
# Avg acc (val): 0.9770
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 26/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 26 result:
# Avg loss (train): 0.0467
# Avg acc (train): 0.8871
# Avg loss (val): 0.0147
# Avg acc (val): 0.9693
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 27/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 27 result:
# Avg loss (train): 0.0403
# Avg acc (train): 0.9015
# Avg loss (val): 0.0091
# Avg acc (val): 0.9807
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 28/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 28 result:
# Avg loss (train): 0.0440
# Avg acc (train): 0.8967
# Avg loss (val): 0.0109
# Avg acc (val): 0.9760
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 29/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 29 result:
# Avg loss (train): 0.0397
# Avg acc (train): 0.9051
# Avg loss (val): 0.0069
# Avg acc (val): 0.9823
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 30/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 30 result:
# Avg loss (train): 0.0402
# Avg acc (train): 0.9015
# Avg loss (val): 0.0166
# Avg acc (val): 0.9530
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 31/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 31 result:
# Avg loss (train): 0.0381
# Avg acc (train): 0.9087
# Avg loss (val): 0.0042
# Avg acc (val): 0.9903
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 32/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 32 result:
# Avg loss (train): 0.0368
# Avg acc (train): 0.9103
# Avg loss (val): 0.0078
# Avg acc (val): 0.9800
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 33/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 33 result:
# Avg loss (train): 0.0348
# Avg acc (train): 0.9157
# Avg loss (val): 0.0075
# Avg acc (val): 0.9807
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 34/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 34 result:
# Avg loss (train): 0.0325
# Avg acc (train): 0.9193
# Avg loss (val): 0.0119
# Avg acc (val): 0.9737
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 35/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 35 result:
# Avg loss (train): 0.0330
# Avg acc (train): 0.9196
# Avg loss (val): 0.0060
# Avg acc (val): 0.9870
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 36/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 36 result:
# Avg loss (train): 0.0334
# Avg acc (train): 0.9185
# Avg loss (val): 0.0059
# Avg acc (val): 0.9857
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 37/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 37 result:
# Avg loss (train): 0.0309
# Avg acc (train): 0.9269
# Avg loss (val): 0.0053
# Avg acc (val): 0.9867
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 38/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 38 result:
# Avg loss (train): 0.0325
# Avg acc (train): 0.9264
# Avg loss (val): 0.0087
# Avg acc (val): 0.9793
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 39/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 39 result:
# Avg loss (train): 0.0307
# Avg acc (train): 0.9248
# Avg loss (val): 0.0059
# Avg acc (val): 0.9887
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 40/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 40 result:
# Avg loss (train): 0.0313
# Avg acc (train): 0.9265
# Avg loss (val): 0.0052
# Avg acc (val): 0.9877
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 41/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 41 result:
# Avg loss (train): 0.0292
# Avg acc (train): 0.9313
# Avg loss (val): 0.0051
# Avg acc (val): 0.9877
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 42/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 42 result:
# Avg loss (train): 0.0281
# Avg acc (train): 0.9339
# Avg loss (val): 0.0059
# Avg acc (val): 0.9907
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 43/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 43 result:
# Avg loss (train): 0.0278
# Avg acc (train): 0.9365
# Avg loss (val): 0.0058
# Avg acc (val): 0.9887
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 44/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 44 result:
# Avg loss (train): 0.0269
# Avg acc (train): 0.9320
# Avg loss (val): 0.0070
# Avg acc (val): 0.9860
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 45/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 45 result:
# Avg loss (train): 0.0286
# Avg acc (train): 0.9321
# Avg loss (val): 0.0057
# Avg acc (val): 0.9843
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 46/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 46 result:
# Avg loss (train): 0.0250
# Avg acc (train): 0.9396
# Avg loss (val): 0.0041
# Avg acc (val): 0.9913
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 47/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 47 result:
# Avg loss (train): 0.0254
# Avg acc (train): 0.9415
# Avg loss (val): 0.0040
# Avg acc (val): 0.9897
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 48/100
# ----------
# Training batch 900/937.5
# Validation batch 300/375
# Epoch 48 result:
# Avg loss (train): 0.0221
# Avg acc (train): 0.9485
# Avg loss (val): 0.0039
# Avg acc (val): 0.9913
# ----------
#
# Model saved at: /content/drive/MyDrive/silverline/cucumber/function2/VGG16_torch_model.pt
# Epoch 49/100
# ----------
# Training batch 500/937.5

# %%
eval_model(model, criterion)
# Out:
# Evaluating model
# ----------
# Test batch 0/375
# /tmp/ipykernel_26/1779223084.py:21: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs, labels = Variable(inputs.cuda(), volatile=True), Variable(labels.cuda(), volatile=True)
# Test batch 300/375
# Evaluation completed in 0m 22s
# Avg loss (test): 0.0028
# Avg acc (test): 0.9947
# ----------

# %%
visualize_model(model, num_images=10)
# Out:
# /tmp/ipykernel_26/642155024.py:15: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs, labels = Variable(inputs.cuda(), volatile=True), Variable(labels.cuda(), volatile=True)
# Ground truth:
# Prediction:
# Ground truth:
# Prediction:
