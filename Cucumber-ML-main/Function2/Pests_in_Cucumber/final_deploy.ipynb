# %%
# !git clone https://github.com/WongKinYiu/yolov7

# %%
# %cd yolov7

# %%
import torch
from pathlib import Path
import cv2
import os

# Load the saved model weights
model_path = "./weights/best_yolov7_weights.pt"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Replace 'your_image_path.jpg' with the path to the image you want to predict
image_path = "./UnseenTestImages/3.jpg"

# %%
# Run inference
# !python detect.py --weights {model_path} --img-size 640 --conf 0.1 --source {image_path} --device {device}
# Out:
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
#
# The image with the result is saved in: runs\detect\exp\3.jpg
# Predicted class: Pumpkin Beetle, Confidence: 0.2206
# Predicted class: Fruit fly, Confidence: 0.2653
# Predicted class: Fruit fly, Confidence: 0.2916
# Predicted class: Pumpkin Beetle, Confidence: 0.2956
# Results saved to output_results.txt
# YOLOR  274b380 torch 2.1.2+cpu CPU
#
# Model Summary: 314 layers, 36503348 parameters, 6194944 gradients

# %%
# Read the saved results from the text file
output_file_path = 'output_results.txt'
with open(output_file_path, 'r') as file:
    saved_results = file.read()

# Display the saved results
print(saved_results)
# Out:
# Predicted class: Pumpkin Beetle, Confidence: 0.2206
# Predicted class: Fruit fly, Confidence: 0.2653
# Predicted class: Fruit fly, Confidence: 0.2916
# Predicted class: Pumpkin Beetle, Confidence: 0.2956

# %%
# Extract imageName from the image path
image_name = Path(image_path).name
# Display the inference for the provided image
from IPython.display import Image, display

# Display the output image
output_image_path = f'./runs/detect/exp/{image_name}'
display(Image(filename=output_image_path))
